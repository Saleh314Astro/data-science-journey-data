# %% [markdown]
# <div style="border-left: 6px solid #7B5EA7; padding: 14px 18px; background: #f5f2fb; border-radius: 8px;">
# <h1 style="color:#2A2440; margin:0;">First Contact</h1>
# <h2 style="color:#7B5EA7; margin:4px 0 10px 0;" dir="rtl">اللقاء الأول</h2>
# <p style="color:#2A2440;">Your mission's data, first sight. Ten minutes: load it, look at it, plot it — then answer two questions on paper.</p>
# <p dir="rtl" style="color:#2A2440;">بيانات قضيتك، أول نظرة: حمّلها، تأمّلها، ارسمها — ثم أجب عن سؤالين على الورق.</p>
# </div>

# %%
# ── The ritual: load YOUR mission's data ─────────────────────────
# Uncomment YOUR mission's line(s) only, then run.
import pandas as pd
import matplotlib.pyplot as plt

base = "https://raw.githubusercontent.com/Saleh314Astro/data-science-journey-data/main/projects/"

# 1 · We Checked — تحقّقنا  (this mission loads TWO files)
# df  = pd.read_csv(base + "saudi_vs_world/saudi_annual.csv", parse_dates=["date"])
# df2 = pd.read_csv(base + "saudi_vs_world/world_annual.csv", parse_dates=["date"])

# 2 · The Planet Hunter — صائد الكواكب
# df = pd.read_csv(base + "kepler_lightcurve/clean.csv")

# 3 · The Sun's Heartbeat — نبض الشمس
# df = pd.read_csv(base + "sunspots/clean.csv", parse_dates=["date"])

# 4 · Our City's Sky — سماء مدينتنا
# df = pd.read_csv(base + "riyadh_station/clean.csv", parse_dates=["date"])

# 5 · The Rising Ocean — المحيط الصاعد
# df = pd.read_csv(base + "sea_level/clean.csv", parse_dates=["date"])

if "df" in dir():
    print("Loaded:", len(df), "rows,", len(df.columns), "columns")
else:
    print("Nothing loaded yet - uncomment your mission's line above, then run this cell again.")

# %%
# ── Look before you compute ──────────────────────────────────────
from IPython.display import display
display(df.head())
df.describe()

# %%
# ── First plot ───────────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(10, 4))

# YOUR CODE HERE - put your two columns into the plot:
# ax.plot(df["..."], df["..."], lw=0.8)

ax.set_xlabel("...")
ax.set_ylabel("...")
ax.set_title("First sight of my mission's data")
plt.show()

# %% [markdown]
# <div style="border-left: 4px solid #2f9e94; padding: 10px 16px;">
#
# ### Two questions — on paper, not in the notebook
#
# **1 · One honest observation: what does your data actually show at first glance?**
# <p dir="rtl">ملاحظة واحدة صادقة: ما الذي تُظهره بياناتك فعلاً من أول نظرة؟</p>
#
# **2 · One question the data made you ask.**
# <p dir="rtl">سؤال واحد دفعتك البيانات إلى طرحه.</p>
#
# </div>

# %% [markdown]
# <div style="border-left: 6px solid #2A2440; padding: 12px 18px; background:#faf9fc; border-radius: 8px;">
#
# **AI rule from today:** it may draft code — every line you keep, you must explain in your own words. If you cannot explain it, delete it.
#
# <p dir="rtl"><b>قاعدة الذكاء الاصطناعي من اليوم:</b> له أن يكتب مسودة الكود — لكن كل سطر تُبقيه عليك أن تشرحه بكلماتك. وما لا تستطيع شرحه، احذفه.</p>
#
# </div>
